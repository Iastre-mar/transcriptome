# %%
import pandas as pd

# %%
table = pd.read_table('/home/iastre/Документы/лаба/test2.format6.out')

# %%
table.iloc[-1] = table.columns

# %%
table
# Out:
#          K00292:317:HWLJ2BBXX:5:1101:23622:1244  uv:KF853601.1:1021-3588  \
# 0        K00292:317:HWLJ2BBXX:5:1101:11830:1349    uv:J02482.1:1-5386-49
# 1        K00292:317:HWLJ2BBXX:5:1101:23652:1402  uv:KF853601.1:1021-3588
# 2        K00292:317:HWLJ2BBXX:5:1101:14712:1666    uv:J02482.1:1-5386-49
# 3         K00292:317:HWLJ2BBXX:5:1101:3437:1754    uv:J02482.1:1-5386-49
# 4        K00292:317:HWLJ2BBXX:5:1101:25378:1859    uv:J02482.1:1-5386-49
# ...                                         ...                      ...
# 327724  K00292:317:HWLJ2BBXX:5:2228:23043:47964       uv:NGB00756.1:1-65
# 327725  K00292:317:HWLJ2BBXX:5:2228:23043:47964       uv:NGB00755.1:1-65
# 327726  K00292:317:HWLJ2BBXX:5:2228:20364:48772    uv:J02482.1:1-5386-49
# 327727  K00292:317:HWLJ2BBXX:5:2228:11556:48843    uv:J02482.1:1-5386-49
# 327728   K00292:317:HWLJ2BBXX:5:1101:23622:1244  uv:KF853601.1:1021-3588
#
#         100.000  74  0  0.1   2  75  1312  1239  2.79e-33   148
# ...

# %%
table = table[table['100.000'].astype('float64') > 95]

# %%
25 / 35
# Out:
# 0.7142857142857143

# %%
pd.DataFrame(table.groupby(['uv:KF853601.1:1021-3588'])['74'].agg('count')).sort_values(by='74',ascending=False).head(50)
# Out:
#                                74
# uv:KF853601.1:1021-3588
# uv:J02482.1:1-5386-49       20228
# uv:KF853601.1:1021-3588      3979
# uv:NGB00847.1:1-64           3127
# uv:JX069762.1:1-134          3085
# uv:JX069762.1:9774-9902-49   3077
# uv:JX069764.1:9741-9848-49   3064
# uv:JX069764.1:1-100          3062
# uv:NGB01029.1:1-66           3032
# uv:NGB00868.1:1-66           3028
# uv:NGB01041.1:1-66           3028
# uv:NGB00363.1:1-34           3028
# uv:NGB01058.1:1-66           3028
# uv:NGB01048.1:1-66           3027
# uv:NGB01075.1:1-66           3026
# uv:NGB01045.1:1-66           3025
# uv:NGB01052.1:1-66           3025
# uv:NGB01030.1:1-66           3024
# uv:NGB01053.1:1-66           3024
# uv:NGB01046.1:1-66           3023
# uv:NGB00856.1:1-64           3023
# uv:NGB01038.1:1-66           3023
# uv:NGB00869.1:1-66           3023
# uv:NGB00848.1:1-64           3022
# uv:NGB01031.1:1-66           3022
# uv:NGB01047.1:1-66           3022
# uv:NGB01034.1:1-66           3021
# ...
